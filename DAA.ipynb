# %% [markdown]
# <a href="https://colab.research.google.com/github/Navya3327/FSAD/blob/main/DAA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

arr = list(map(int, input("Enter elements: ").split()))
target = int(input("Enter target value: "))

result = linear_search(arr, target)

if result == -1:
    print("Element not found")
else:
    print("Element found at index", result)
# Out:
# Enter elements: 34
# Enter target value: 3
# Element not found
